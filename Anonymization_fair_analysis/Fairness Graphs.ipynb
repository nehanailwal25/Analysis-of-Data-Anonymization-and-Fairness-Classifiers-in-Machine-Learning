# %% [markdown]
# # Fairness Analysis

# %% [markdown]
# ### Importing modules

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Correctness Measures

# %%
correct_measures = pd.read_csv(r'C:\Users\Neha Sharma\Desktop\Security and Privacy\Project\Github\Final Results\Graphs\Correctness_measures.csv');

# %%
correct_measures.head()
# Out:
#       Algorithms  Accuracy  Precision    Recall  F1-Score
# 0  Zafar_FairAcc  0.820004   0.704641  0.489449  0.577655
# 1  Zafar_AccFair  0.763986   0.529362  0.554807  0.541786
# 2        Feldman  0.771578   0.636205  0.214244  0.320544
# 3        Kamiran  0.763691   0.520204  0.777257  0.623267

# %%
correct_measures.plot(x="Algorithms", y=["Accuracy", "Precision", "Recall", "F1-Score"], kind="bar", ylabel="Probability", figsize=(12,10), legend={'reverse'}, rot=25)
# Out:
# <AxesSubplot:xlabel='Algorithms', ylabel='Probability'>

# %% [markdown]
# ### Fairness Measures

# %%
fair_measures = pd.read_csv(r'C:\Users\Neha Sharma\Desktop\Security and Privacy\Project\Github\Final Results\Graphs\Fairness_measures.csv');

# %%
fair_measures.head()
# Out:
#       Algorithms        DI      TPRB      TNRB    1_TPRB    1_TNRB
# 0  Zafar_FairAcc  0.745263  0.178031  0.011964  0.821969  0.988036
# 1  Zafar_AccFair  0.945859  0.189298  0.045399  0.810702  0.954601
# 2        Feldman  0.788624  0.039153  0.012414  0.960847  0.987586
# 3        Kamiran  0.949811  0.152737  0.082716  0.847263  0.917284

# %%
fair_measures.plot(x="Algorithms", y=["DI", "1_TPRB", "1_TNRB"], ylabel="Probability", kind="bar", figsize=(12,10), legend={'reverse'}, rot=25)
# Out:
# <AxesSubplot:xlabel='Algorithms', ylabel='Probability'>
